# %% [markdown]
# # Time Series with statsmodels
#
# Formatting date indices, moving averages and seasonal decomposition.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %% [markdown]
# ## Create Sample Dataset

# %%
dates=pd.date_range('2023-01-01',periods=36,freq='M')

sales=[100,105,110,120,130,140,145,150,160,170,180,190,
195,200,205,215,225,235,240,245,255,265,275,285,
290,295,305,315,325,335,340,345,355,365,375,390]

df=pd.DataFrame({'Date':dates,'Sales':sales})
df.head()

# %% [markdown]
# ## Format Date Index

# %%
df['Date']=pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)
df.head()

# %% [markdown]
# ## Plot Time Series

# %%
plt.figure(figsize=(10,5))
plt.plot(df.index,df['Sales'],marker='o')
plt.title('Monthly Sales')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Moving Average

# %%
df['MA_3']=df['Sales'].rolling(window=3).mean()
df[['Sales','MA_3']].head(10)

# %% [markdown]
# ## Plot Moving Average

# %%
plt.figure(figsize=(10,5))
plt.plot(df.index,df['Sales'],label='Sales')
plt.plot(df.index,df['MA_3'],linewidth=3,label='3-Month MA')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Seasonal Decomposition

# %%
result=seasonal_decompose(df['Sales'],model='additive',period=12)
result.plot()
plt.show()

# %% [markdown]
# ## Individual Components

# %%
plt.figure(figsize=(10,4))
plt.plot(result.trend)
plt.title('Trend')
plt.grid(True)
plt.show()

plt.figure(figsize=(10,4))
plt.plot(result.seasonal)
plt.title('Seasonality')
plt.grid(True)
plt.show()

plt.figure(figsize=(10,4))
plt.plot(result.resid)
plt.title('Residual')
plt.grid(True)
plt.show()
